# %%
import pandas as pd

# %%
df=pd.read_csv("universal_top_spotify_songs.csv")
df.head()
# Out:
#                spotify_id          name        artists  daily_rank  \
# 0  7gaA3wERFkFkgivjwbSvkG     yes, and?  Ariana Grande           1
# 1  3rUGC1vUpkDG9CZFHMur1t        greedy     Tate McRae           2
# 2  0R6NfOiLzLj4O5VbYSJAjf     La Diabla           Xavi           3
# 3  4xhsWYTOGcal8zt0J161CU   Lovin On Me    Jack Harlow           4
# 4  1BxfuPKGuaTgP7aM0Bbdwr  Cruel Summer   Taylor Swift           5
#
#    daily_movement  weekly_movement country snapshot_date  popularity  \
# 0              49               49     NaN    2024-01-14           0
# 1              -1               -1     NaN    2024-01-14         100
# 2              -1               -1     NaN    2024-01-14          97
# 3              -1               -1     NaN    2024-01-14          99
# 4              -1               -1     NaN    2024-01-14          99
#
#    is_explicit  ...  key loudness mode  speechiness  acousticness  \
# 0         True  ...    1   -6.513    1       0.0505        0.1980
# ...
